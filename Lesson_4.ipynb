# %% [markdown]
# # Part 1

# %% [markdown]
# __1.__ Решите систему уравнений методом Гаусса:
#
# $$\begin{cases}
# x_{1}+x_{2}-x_{3}-2x_{4}=0, \\
# 2x_{1}+x_{2}-x_{3}+x_{4}=-2, \\
# x_{1}+x_{2}-3x_{3}+x_{4}=4.
# \end{cases}$$

# %% [markdown]
# первое, что бросается в глаза, это то, что переменных 4, а уравнений 3. значит будет недостаточно информации чтобы решить полностью<br>
# +1 +1 -1 -2|<br>
# +2 +1 -1 +1| <br>
# +1 +1 -3 +1| <br>
# сначала поменяю элемент 21, для этого из второй строки вычту первую умноженную на 2<br>
# дальше меняю элемент 31, вычитая из третьей строки первую <br>
# +1 +1 -1 -2|+0 <br>
# +0 -1 -3 -2|-2 <br>
# +0 +0 -2 +3|+4 <br>
# +0 +0 +0 +0| 0 - этой строки нет изначально, но визуально для себя сделал лесенку<br>
# n = 4, ранг обычной матрицы 3, ранг расширенной 3, значит решений бесконечное множество <br>
# x4 = c<br>
# -2x3 + 3c = 4, x3 = (4-3c)/(-2)<br>
# -x2 - ((4-3c)/(-2)) -2c = -2, x2 = -1(-2 + 2c + (4-3c/-2)) = 2 - 2c + (4-3c/-2)<br>
# x1 + 2 - 2c + (4-3c/-2) - (4-3c)/(-2) - 2c = 0, x1 = 4c-2<br>

# %% [markdown]
# __2.__ Проверьте на совместность и выясните, сколько решений будет иметь система линейных уравнений:
#
#    а) $\begin{cases}
# 3x_{1}-x_{2}+x_{3}=4, \\
# 2x_{1}-5x_{2}-3x_{3}=-17, \\
# x_{1}+x_{2}-x_{3}=0;
# \end{cases}$
#
#    б) $\begin{cases}
# 2x_{1}-4x_{2}+6x_{3}=1, \\
# x_{1}-2x_{2}+3x_{3}=-2, \\
# 3x_{1}-6x_{2}+9x_{3}=5;
# \end{cases}$
#
#    в) $\begin{cases}
# x_{1}+2x_{2}+5x_{3}=4, \\
# 3x_{1}+x_{2}-8x_{3}=-2.
# \end{cases}$

# %% [markdown]
# а)<br>
# +3 -1 +1|+04<br>
# +2 -4 -3|-17<br>
# +1 +1 -1|+00<br>
# вторая строка минус третья * 2<br>
# +3 -1 +1|+04<br>
# +0 -6 -1|-17<br>
# +1 +1 -1|+00<br>
# третья * 3  минус первая<br>
# +3 -1 +1|+04<br>
# +0 -6 -1|-17<br>
# +0 +6 -4|-04<br>
# Ответ: а = одно решение<br>
# б)<br>
# +2 -4 +6|+1<br>
# +1 -2 +3|-2<br>
# +3 -6 +9|+5<br>
# все три строки линейно зависимы: вторая умноженная на 3 это третья строка, можно вычеркнуть 3 строку, а первая строка это вторая умноженная на 2, вторую можно вычеркнуть <br>
# остаётся одно уравнение, но элементы расширенной матрицы никуда не делись, следовательно ранг не совпадает, значит решений нет<br>
# Ответ: б = нет решений<br>
# в)<br>
# +1 +2 +5|+4<br>
# +3 +1 -8|-2<br>
# ранг матриц будет совпадать, потому что не получится обнулить вторую строку оставив элементы расширенной матрицы, значит<br>
# Ответ: множество решений

# %% [markdown]
# __3.__ Проверьте на совместность и выясните, сколько решений будет иметь система линейных уравнений, заданная расширенной матрицей:
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 3 & -2 & 4\\
# 0 & 5 & 0 & 1\\
# 0 & 0 & 3 & 0\\
# 0 & 0 & 0 & 2
# \end{matrix}\right|
# \begin{matrix}
# 3\\
# 2\\
# 4\\
# 1
# \end{matrix}
# \end{pmatrix}.$$

# %% [markdown]
# ранг матриц одинаковый, тк не получится избавиться от какой-либо строки матрицы или расширенной матрицы <br>
# и ранг совпадает с количеством неизвестных == 4<br>
# Ответ: система будет иметь одно решение<br>

# %% [markdown]
# __4.__ Дана система линейных уравнений, заданная расширенной матрицей:
#
# $$\tilde{A}=\begin{pmatrix}
# \left.\begin{matrix}
# 1 & 2 & 3\\
# 4 & 5 & 6\\
# 7 & 8 & 9
# \end{matrix}\right|
# \begin{matrix}
# a\\
# b\\
# c
# \end{matrix}
# \end{pmatrix}.$$
#
# Найдите соотношение между параметрами $a$, $b$ и $c$, при которых система считается несовместной.

# %% [markdown]
# 1 2 3|a <br>
# 4 5 6|b <br>
# 7 8 9|c <br>
# чтобы найти соотношение мне необходимо привести матрицу к виду, в котором она решается методом Гаусса <br>
# из третьей строки вычитаю первую умноженную на 7<br>
# из второй строки вычитаю первую умноженную на 4<br>
# +1 +2 +03|a <br>
# +0 -3 -06|b-4а <br>
# +0 -6 -12|c-7a <br>
# из третьей вычту вторую умноженную на 2<br>
# +1 +2 +3|a <br>
# +0 -3 -6|b-4а <br>
# +0 +0 +0|c-7a - 2(b-4a) <br><br>
# c-7a - 2(b-4a) = 0, c-7a = 2b-8a, c = 2b-a<br>
# -2b = -a-c, b = (a-c)/2<br>
# a = 2b-c<br>

# %% [markdown]
# # part 2

# %% [markdown]
# __1.__ Решите систему уравнений методом Крамера:
#
#    а) $\begin{cases}
# x_{1}-2x_{2}=1 \\
# 3x_{1}-4x_{2}=7
# \end{cases}$
#
#    б) $\begin{cases}
# 2x_{1}-x_{2}+5x_{3}=10 \\
# x_{1}+x_{2}-3x_{3}=-2 \\
# 2x_{1}+4x_{2}+x_{3}=1
# \end{cases}$

# %% [markdown]
# a)<br>
# +1 -2|1 <br>
# +3 -4|7 <br>
# detA = (1*(-4)-3*(-2)) = -4 + 6 =2<br>
# <br>
# 1 -2<br>
# 7 -4<br>
# detA1 = (1*(-4)-7*(-2)) = -4 + 14 = 10<br>
# <br>
# 1 1<br>
# 3 7<br>
# detA2 = 1 * 7 - 3 * 1 = 4 <br><br>
# x1 = 10/2 = 5<br>
# x2 = 4/2 = 2<br>

# %% [markdown]
# б)<br>
# +2 -1 +5|10<br>
# +1 +1 -3|-2<br>
# +2 +4 +1|1<br>
# detA = 2 * (1 * 1 - 4 * (-3))-1 * ((-1) * 1 - 4 * 5)+ 2 * ((-1) * (-3) - 1 * 5) = 43<br>
# <br>
# 10 -1 +5<br>
# -2 +1 -3<br>
# +1 +4 +1<br>
# detA1 = 10 * (1 * 1 - 4 * (-3)) - (-2) * ((-1) * 1 - 4 * 5) + 1 * ((-1) * (-3) - 1 * 5) = 86<br>
# <br>
# +2 10 +5<br>
# +1 -2 -3<br>
# +2 +1 +1<br>
# detA2 = 2 * ((-2) * 1 - 1 * (-3)) - 1 * (10 * 1 - 1 * 5) + 2 * (10 * (-3) - (-2) * 5) = -43<br>
# <br>
# 2 -1 10<br>
# 1 +1 -2<br>
# 2 +4 +1<br>
# detA3 = 2 * (1 * 1 - 4 * (-2)) - 1 * ((-1) * 1 - 4 * 10) + 2 * ((-1) * (-2) - 1 * 10) = 43<br>
# <br>
# x1 = 86/43 = 2 <br>
# x2 = -43/43 = -1<br>
# x3 = 43/43 = 1<br>

# %% [markdown]
# __2*.__ Найдите $L$-матрицу $LU$-разложения для матрицы коэффициентов:
#
#    а)$$\begin{pmatrix}
# 1 & 2 & 4 \\
# 2 & 9 & 12 \\
# 3 & 26 & 30
# \end{pmatrix}$$
#
#    б)$$\begin{pmatrix}
# 1 & 1 & 2 & 4\\
# 2 & 5 & 8 & 9\\
# 3 & 18 & 29 & 18\\
# 4 & 22 & 53 & 33
# \end{pmatrix}$$

# %% [markdown]
# __3*.__ Решите систему линейных уравнений методом $LU$-разложения:
#
# $$\begin{cases}
# 2x_{1}+x_{2}+3x_{3}=1 \\
# 11x_{1}+7x_{2}+5x_{3}=-6 \\
# 9x_{1}+8x_{2}+4x_{3}=-5
# \end{cases}$$

# %% [markdown]
# __4*.__ Решите систему линейных уравнений методом Холецкого:
#
# $$\begin{cases}
# 81x_{1}-45x_{2}+45x_{3}=531 \\
# -45x_{1}+50x_{2}-15x_{3}=-460 \\
# 45x_{1}-15x_{2}+38x_{3}=193
# \end{cases}$$

# %% [markdown]
# __5*.__ Напишите на Python программу с реализацией одного из изученных алгоритмов решения СЛАУ.
